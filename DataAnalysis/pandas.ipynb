# %%
import pandas as pd
data = {
    'color': ['green', 'yellow', 'red', 'blue', 'white'],
    'object': ['ball', 'pen', 'pencil', 'paper', 'mug'],
    'price': [1.2, 1.0, 0.6, 0.9, 1.5]
}

df = pd.DataFrame(data)

# %%
df2 = pd.DataFrame(data, columns = ['object','price'])
df2
# Out:
#    object  price
# 0    ball    1.2
# 1     pen    1.0
# 2  pencil    0.6
# 3   paper    0.9
# 4     mug    1.5

# %%
df2.columns
# Out:
# Index(['object', 'price'], dtype='str')

# %%
df2.object
df
# Out:
#     color  object  price
# 0   green    ball    1.2
# 1  yellow     pen    1.0
# 2     red  pencil    0.6
# 3    blue   paper    0.9
# 4   white     mug    1.5

# %%
df.loc[2:4]
# Out:
#    color  object  price
# 2    red  pencil    0.6
# 3   blue   paper    0.9
# 4  white     mug    1.5

# %%
df.loc[[2,4]]
# Out:
#    color  object  price
# 2    red  pencil    0.6
# 4  white     mug    1.5

# %%
df
# Out:
#     color  object  price
# 0   green    ball    1.2
# 1  yellow     pen    1.0
# 2     red  pencil    0.6
# 3    blue   paper    0.9
# 4   white     mug    1.5

# %%
df.iloc[2:4, 1:4]
# Out:
#    object  price
# 2  pencil    0.6
# 3   paper    0.9

# %%
df.loc[2:3, ['object', 'price']]
# Out:
#    object  price
# 2  pencil    0.6
# 3   paper    0.9

# %%
df.columns.name = 'item '
df.loc[[2,4],['object','price' ]]
# Out:
# item    object  price
# index
# 2       pencil    0.6
# 4          mug    1.5

# %%
df['new'] = 12
df
# Out:
# item     color  object  price  new
# index
# 0        green    ball    1.2   12
# 1       yellow     pen    1.0   12
# 2          red  pencil    0.6   12
# 3         blue   paper    0.9   12
# 4        white     mug    1.5   12
